# %%
# ==========================================
# 0️⃣ นำเข้าคลังข้อมูลที่จำเป็น
# ==========================================
import pandas as pd
import numpy as np
import time
from cassandra.cluster import Cluster
from datetime import datetime
import plotly.express as px
from settrade_v2 import Investor

# %%
# ==========================================
# 1️⃣ เชื่อมต่อ Cassandra และสร้าง keyspace + table
# ==========================================
cluster = Cluster(['127.0.0.1'])
session = cluster.connect()

session.execute("""
    CREATE KEYSPACE IF NOT EXISTS data_stock
    WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 1};
""")
session.set_keyspace('data_stock')

session.execute("""
    CREATE TABLE IF NOT EXISTS candlestick_data (
        symbol text,
        time timestamp,
        open_price float,
        high_price float,
        low_price float,
        close_price float,
        volume bigint,
        value float,
        PRIMARY KEY (symbol, time)
    ) WITH CLUSTERING ORDER BY (time ASC);
""")
print("✅ Keyspace และ Table พร้อมใช้งาน!")
# Out:
# ✅ Keyspace และ Table พร้อมใช้งาน!

# %%
# ==========================================
# 2️⃣ เชื่อมต่อ Settrade API
# ==========================================
investor = Investor(
    app_id="kc2VLfCa7PkZSe0W",
    app_secret="aL0MiKbupfsjWDzoRz1lsSgUYy68HkJYjqP2aLMROnI=",
    broker_id="SANDBOX",
    app_code="SANDBOX",
    is_auto_queue=False
)
market = investor.MarketData()

# %%
# ==========================================
# 3️⃣ โหลดรายชื่อหุ้น
# ==========================================
try:
    symbols_df = pd.read_excel("get_stock_name/stocth_names.xlsx")
    symbols = symbols_df['หลักทรัพย์'].dropna().tolist()
except FileNotFoundError:
    print("❌ ไม่พบไฟล์ stocth_names.xlsx ใช้รายชื่อหุ้นที่กำหนดแทน")
    symbols = ["PTT", "AOT", "SCB", "CPALL", "ADVANC"]

# %%
# ==========================================
# 4️⃣ ฟังก์ชันดึงข้อมูล Candlestick
# ==========================================
def get_candlestick_data(symbol):
    try:
        res = market.get_candlestick(
            symbol=symbol,
            interval="1d",
            limit=100,
            normalized=True
        )
        if isinstance(res, dict) and "data" in res:
            return res["data"]
        else:
            return res
    except Exception as e:
        print(f"⚠️ ไม่สามารถดึงข้อมูลของ {symbol}: {e}")
        return None

# %%
# ==========================================
# 5️⃣ ฟังก์ชันบันทึกลง Cassandra
# ==========================================
def insert_financial_data(symbol, res):
    if not res or "time" not in res:
        print(f"⚠️ ไม่มีข้อมูลสำหรับ {symbol}")
        return

    for i in range(len(res["time"])):
        timestamp = datetime.fromtimestamp(res["time"][i])
        session.execute("""
            INSERT INTO candlestick_data (
                symbol, time, open_price, high_price, low_price,
                close_price, volume, value
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        """, (
            symbol,
            timestamp,
            res["open"][i],
            res["high"][i],
            res["low"][i],
            res["close"][i],
            res["volume"][i],
            res["value"][i]
        ))
    print(f"✅ เพิ่มข้อมูล {len(res['time'])} รายการของหุ้น {symbol} สำเร็จ!")

# %%
# ==========================================
# 6️⃣ ดึงและบันทึกข้อมูลหุ้นทั้งหมด
# ==========================================
for symbol in symbols:
    print(f"\n📦 กำลังโหลดข้อมูล {symbol} ...")
    res = get_candlestick_data(symbol)
    insert_financial_data(symbol, res)
    time.sleep(2)

print("\n🎉 เสร็จสิ้นการโหลดข้อมูลทั้งหมด!")
# Out:
# 📦 กำลังโหลดข้อมูล 24CS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้
สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CHOW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CHOW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CIG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CIG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CIMBT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CIMBT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CITY ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CITY สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CIVIL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CIVIL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CK ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CK สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CKP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CKP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CMAN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CMAN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CMC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CMC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CMO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CMO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CMR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CMR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CNT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CNT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล COCOCO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น COCOCO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล COLOR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น COLOR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล COM7 ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น COM7 สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล COMAN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น COMAN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPALL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPALL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPANEL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPANEL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPAXT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPAXT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPNCG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPNCG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPNREIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPNREIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPTREIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPTREIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CPW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CPW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CRANE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CRANE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CRC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CRC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CRD ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CRD สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CREDIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CREDIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CSC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CSC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CSP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CSP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CSR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CSR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CSS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CSS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CTARAF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CTARAF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CTW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CTW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CV ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CV สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล CWT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น CWT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล D ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น D สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DCC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DCC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DCON ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DCON สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DDD ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DDD สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DELTA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DELTA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DEMCO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DEMCO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DEXON ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DEXON สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DHOUSE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DHOUSE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DIF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DIF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DIMET ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DIMET สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DITTO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DITTO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DMT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DMT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DOD ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DOD สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DOHOME ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DOHOME สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DPAINT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DPAINT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DREIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DREIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DRT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DRT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DTCENT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DTCENT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DTCI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DTCI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DUSIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DUSIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล DV8 ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น DV8 สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EASON ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EASON สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EAST ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EAST สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EASTW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EASTW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ECF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ECF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EE ...
# ⚠️ ไม่สามารถดึงข้อมูลของ EE: Symbol not found [EE]
# ⚠️ ไม่มีข้อมูลสำหรับ EE
#
# 📦 กำลังโหลดข้อมูล EFORL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EFORL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EGATIF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EGATIF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EGCO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EGCO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EKH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EKH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EMC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EMC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EPG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EPG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ERW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ERW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ESTAR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ESTAR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ETC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ETC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ETE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ETE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ETL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ETL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EURO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EURO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล EVER ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น EVER สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล F&D ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น F&D สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FANCY ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FANCY สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FLOYD ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FLOYD สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FMT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FMT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FNS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FNS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FORTH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FORTH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FPI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FPI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FPT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FPT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FSMART ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FSMART สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FSX ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FSX สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FTE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FTE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FTI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FTI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FTREIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FTREIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FUTURERT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FUTURERT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล FVC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น FVC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GABLE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GABLE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GAHREIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GAHREIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GBX ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GBX สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GCAP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GCAP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GEL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GEL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GENCO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GENCO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GFC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GFC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GFPT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GFPT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GGC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GGC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GJS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GJS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GL ...
# ⚠️ ไม่สามารถดึงข้อมูลของ GL: Symbol not found [GL]
# ⚠️ ไม่มีข้อมูลสำหรับ GL
#
# 📦 กำลังโหลดข้อมูล GLAND ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GLAND สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GLOBAL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GLOBAL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GLOCON ...
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น GLOCON สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GLORY ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GLORY สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GPI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GPI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GPSC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GPSC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GRAMMY ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GRAMMY สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GRAND ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GRAND สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GREEN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GREEN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GROREIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GROREIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GSTEEL ...
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น GSTEEL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GTB ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GTB สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GTV ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GTV สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GULFI ...
# ⚠️ ไม่สามารถดึงข้อมูลของ GULFI: Symbol not found [GULFI]
# ⚠️ ไม่มีข้อมูลสำหรับ GULFI
#
# 📦 กำลังโหลดข้อมูล GUNKUL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GUNKUL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GVREIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GVREIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล GYT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น GYT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HANA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HANA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HARN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HARN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HEALTH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HEALTH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HENG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HENG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HFT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HFT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HMPRO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HMPRO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HPF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HPF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HPT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HPT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HTC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HTC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HTECH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HTECH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HUMAN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HUMAN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HYDRO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HYDRO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล HYDROGEN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น HYDROGEN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล I2 ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น I2 สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ICC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ICC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ICHI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ICHI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ICN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น
...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น M-PAT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล MPJ ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น MPJ สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล MSC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น MSC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล MST ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น MST สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล M-STOR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น M-STOR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล MTC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น MTC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล MTI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น MTI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล MTW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น MTW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล MUD ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น MUD สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล MVP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น MVP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NAM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NAM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NAT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NAT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NATION ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NATION สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NCAP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NCAP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NCH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NCH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NCL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NCL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NCP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NCP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NDR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NDR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NEO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NEO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NEP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NEP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NER ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NER สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NETBAY ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NETBAY สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NEW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NEW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NEWS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NEWS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NEX ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NEX สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NFC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NFC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NKI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NKI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NKT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NKT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NNCL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NNCL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NOBLE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NOBLE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NOVA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NOVA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NPK ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NPK สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NRF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NRF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NSL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NSL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NTSC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NTSC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NTV ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NTV สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NV ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NV สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NVD ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NVD สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NWR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NWR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล NYT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น NYT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล OCC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น OCC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล OGC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น OGC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล OHTL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น OHTL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล OKJ ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น OKJ สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ONEE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ONEE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล OR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น OR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ORI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ORI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ORN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ORN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล OSP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น OSP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PACO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PACO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PAF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PAF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PANEL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PANEL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PAP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PAP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PATO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PATO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PB ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PB สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PCC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PCC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PCE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PCE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PCSGH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PCSGH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PDG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PDG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PDJ ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PDJ สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PEACE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PEACE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PEER ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PEER สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PERM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PERM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PHG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PHG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PHOL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PHOL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PICO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PICO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PIMO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PIMO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PIN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PIN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PIS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PIS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PJW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PJW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PK ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PK สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PLANB ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PLANB สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PLANET ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PLANET สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PLAT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PLAT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PLE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PLE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PLT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PLT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PLUS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PLUS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PMC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PMC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PMTA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PMTA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล POLY ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น POLY สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล POPF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น POPF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PORT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PORT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PPM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PPM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PPP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PPP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PPPM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PPPM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PPS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PPS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PQS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PQS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PR9 ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PR9 สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRAKIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRAKIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRAPAT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRAPAT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PREB ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PREB สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRECHA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRECHA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRIME ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRIME สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRIN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRIN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRINC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRINC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PROEN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PROEN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PROS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PROS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PROSPECT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PROSPECT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PROUD ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PROUD สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PRTR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PRTR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PSG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PSG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PSH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PSH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PSL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PSL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PSP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PSP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PSTC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PSTC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PTC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PTC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PTECH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PTECH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PTG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PTG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PTL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PTL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PTT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PTT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PTTEP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PTTEP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PTTGC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PTTGC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล PYLON ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น PYLON สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล Q-CON ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น Q-CON สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล QH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น QH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล QHBREIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น QHBREIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล QHHRREIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น QHHRREIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล QHOP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น QHOP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล QLT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น QLT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล QTC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น QTC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล QTCG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น QTCG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RABBIT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RABBIT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RAM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RAM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RATCH ...
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น RATCH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RBF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RBF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RCL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RCL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล READY ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น READY สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RICHY ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RICHY สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RJH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RJH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RML ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RML สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ROCK ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ROCK สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ROCTEC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ROCTEC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ROH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ROH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ROJNA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ROJNA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RPC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RPC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RPH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RPH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RSP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RSP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล RWI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น RWI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล S ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น S สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล S&J ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น S&J สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล S11 ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น S11 สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล SA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น SA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล SAAM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น SAAM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล SABINA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น SABINA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล SABUY ...
# ⚠️ ไม่สามารถดึงข้อมูลของ SABUY: Symbol not found [SABUY]
# ⚠️ ไม่มีข้อมูลสำหรับ SABUY
#
# 📦 กำลังโหลดข้อมูล SAF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น SAF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล SAFARI ...
# ⚠️ ไม่สามารถดึงข้อมูลของ SAFARI: Symbol not found [SAFARI]
# ⚠️ ไม่มีข้อมูลสำหรับ SAFARI
#
# 📦 กำลังโหลดข้อมูล SAFE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น S
...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TSTE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TSTH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TSTH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TTA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTB ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TTB สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTCL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TTCL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TTI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTLPF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TTLPF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TTT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TTW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TU ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TU สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TU-PF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TU-PF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TURTLE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TURTLE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TVDH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TVDH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TVH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TVH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TVO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TVO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TVT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TVT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TWP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TWP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TWPC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TWPC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TWZ ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TWZ สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TYCN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น TYCN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UAC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UAC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UBA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UBA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UBE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UBE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UBIS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UBIS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UEC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UEC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UKEM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UKEM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UMI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UMI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UMS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UMS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UNIQ ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UNIQ สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UOBKH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UOBKH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UPF ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UPF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UPOIC ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UPOIC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UREKA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UREKA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UTP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UTP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UV ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UV สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UVAN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น UVAN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VARO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VARO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VCOM ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VCOM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VGI ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VGI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VIBHA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VIBHA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VIH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VIH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VNG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VNG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VPO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VPO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VRANDA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VRANDA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VS ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น VS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WACOAL ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WACOAL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WARRIX ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WARRIX สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WAVE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WAVE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WELL ...
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น WELL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WFX ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WFX สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WGE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WGE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WHA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHABT ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WHABT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHAIR ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WHAIR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHART ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WHART สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHAUP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WHAUP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WICE ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WICE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WIIK ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WIIK สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WIN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WIN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WINDOW ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WINDOW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WINMED ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WINMED สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WINNER ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WINNER สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WORK ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WORK สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WP ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WPH ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น WPH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล XBIO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น XBIO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล XO ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น XO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล XPG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น XPG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล XYZ ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น XYZ สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล YGG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น YGG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล YONG ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น YONG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล YUASA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น YUASA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ZAA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ZAA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ZEN ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ZEN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ZIGA ...
# ✅ เพิ่มข้อมูล 100 รายการของหุ้น ZIGA สำเร็จ!
#
# 🎉 เสร็จสิ้นการโหลดข้อมูลทั้งหมด!

# %%
# ==========================================
# 7️⃣ วิเคราะห์คุณภาพหุ้น (สมมติข้อมูลพื้นฐานจำลอง)
# ==========================================
data_quality = pd.DataFrame({
    "Symbol": symbols,
    "P/E": np.random.uniform(5, 40, len(symbols)),
    "P/BV": np.random.uniform(0.5, 5, len(symbols)),
    "ROE": np.random.uniform(2, 30, len(symbols)),
    "Dividend": np.random.uniform(0, 8, len(symbols))
})

def classify_quality(row):
    if row["ROE"] > 20 and row["P/E"] < 15 and row["P/BV"] < 2:
        return "Excellent"
    elif row["ROE"] > 15 and row["P/E"] < 20:
        return "Good"
    elif row["ROE"] > 10:
        return "Fair"
    elif row["ROE"] > 5:
        return "Poor"
    else:
        return "Unacceptable"

data_quality["Quality"] = data_quality.apply(classify_quality, axis=1)

# %%
# ==========================================
# 8️⃣ Treemap Divining Based on Quality + Legend อธิบายสี
# ==========================================
treemap_data = data_quality.copy()
treemap_data["Size"] = treemap_data["ROE"]  # ขนาดกล่อง = ROE

# Mapping สีตามระดับ Quality
color_map = {
    "Excellent": "green",
    "Good": "limegreen",
    "Fair": "gold",
    "Poor": "orange",
    "Unacceptable": "red"
}

fig = px.treemap(
    treemap_data,
    path=["Symbol"],      # ถ้ามี Sector: ["Sector","Symbol"]
    values="Size",
    color="Quality",      # ใช้ชื่อ Quality ตรง ๆ
    color_discrete_map=color_map,
    title="📊 Divining Based on Quality: Stock Heatmap",
    custom_data=["ROE", "P/E", "P/BV", "Dividend"]
)

# Tooltip แสดง ROE, P/E, P/BV, Dividend
fig.update_traces(
    texttemplate="%{label}<br>ROE: %{customdata[0]:.2f}",
    hovertemplate=(
        "<b>%{label}</b><br>" +
        "ROE: %{customdata[0]:.2f}<br>" +
        "P/E: %{customdata[1]:.2f}<br>" +
        "P/BV: %{customdata[2]:.2f}<br>" +
        "Dividend: %{customdata[3]:.2f}<extra></extra>"
    )
)

# Legend ชัดเจนด้านข้าง
fig.update_layout(
    legend_title=dict(
        text='📊 Stock Quality Level',
        font=dict(size=15, color="black")
    ),
    legend=dict(
        orientation="v",
        yanchor="top",
        y=1,
        xanchor="right",
        x=1.02,
        title_font_size=12,
        font=dict(size=12),
        itemsizing='constant',
        traceorder='normal'
    )
)

# เพิ่ม annotation อธิบายสีด้านข้าง (ถ้าต้องการ)
annotations = [
    dict(x=1.1, y=1, xref='paper', yref='paper',
         text="<b>Color Legend:</b><br>Green = Excellent<br>Lime = Good<br>Gold = Fair<br>Orange = Poor<br>Red = Unacceptable",
         showarrow=False, align='left', font=dict(size=6))
]
fig.update_layout(annotations=annotations)

fig.show()

# %%
# ==========================================
# 9️⃣ สรุปข้อมูลหุ้นตามคุณภาพ
# ==========================================
summary = data_quality.groupby("Quality").agg({
    "Symbol": "count",
    "ROE": ["mean", "max", "min"],
    "P/E": ["mean", "max", "min"],
    "P/BV": ["mean", "max", "min"],
    "Dividend": ["mean", "max", "min"]
}).reset_index()

summary.columns = ["Quality", "Count", "ROE_mean", "ROE_max", "ROE_min",
                   "PE_mean", "PE_max", "PE_min",
                   "PBV_mean", "PBV_max", "PBV_min",
                   "Dividend_mean", "Dividend_max", "Dividend_min"]

cols_to_show = [
    "Quality", "Count",
    "ROE_mean", "ROE_max", "ROE_min",
    "PE_mean", "PE_max", "PE_min",
    "PBV_mean", "PBV_max", "PBV_min",
    "Dividend_mean", "Dividend_max", "Dividend_min"
]

print("📋 สรุปข้อมูลหุ้นตามคุณภาพ:")
print(summary[cols_to_show])
# Out:
# 📋 สรุปข้อมูลหุ้นตามคุณภาพ:
#         Quality  Count   ROE_mean    ROE_max    ROE_min    PE_mean     PE_max  \
# 0     Excellent     40  24.239191  29.961172  20.294811   9.796820  14.887022
# 1          Fair    422  18.924023  29.930384  10.012438  27.678325  39.898774
# 2          Good    194  22.118190  29.995659  15.118021  12.748192  19.791613
# 3          Poor    167   7.589316   9.982014   5.021706  22.095639  39.941136
# 4  Unacceptable    100   3.309604   4.988172   2.000268  21.903768  39.700060
#
#      PE_min  PBV_mean   PBV_max   PBV_min  Dividend_mean  Dividend_max  \
# 0  5.008258  1.213453  1.962482  0.517377       3.727488      7.787320
# 1  5.891495  2.849913  4.991726  0.518899       4.127206      7.975746
# 2  5.028185  3.112726  4.983473  0.510380       4.033786      7.916271
# 3  5.004009  2.964877  4.998078  0.503963       4.025593      7.974645
# 4  5.007666  2.668443  4.971239  0.529188       4.111796      7.988479
#
#    Dividend_min
# 0      0.382583
# 1      0.011833
# 2      0.028102
# 3      0.078868
# 4      0.053733
